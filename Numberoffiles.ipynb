# %%
import os

def count_files_in_subfolders(main_folder):
    """
    This function walks through each subfolder of the main folder and counts the number of files in each.
    It also prints the total number of files in the delivery folder.
    """
    total_files = 0  # Initialize a counter for the total number of files
    
    for root, dirs, files in os.walk(main_folder):
        # Count files in the current directory
        subfolder_name = os.path.relpath(root, main_folder)
        file_count = len([f for f in files if os.path.isfile(os.path.join(root, f))])
        total_files += file_count  # Add to the total count
        
        # Print the file count for each folder
        print(f"Folder: {subfolder_name}, Number of files: {file_count}")
    
    # Print the total number of files
    print(f"\nTotal number of files in the delivery folder: {total_files}")

# Example usage:
if __name__ == "__main__":
    main_folder_path = "/users/azizkhan/speakers"  # Replace with your main folder path
    count_files_in_subfolders(main_folder_path)
# Out:
# Folder: ., Number of files: 1
# Folder: consents, Number of files: 502
# Folder: delivery, Number of files: 1
# Folder: delivery/4943, Number of files: 270
# Folder: delivery/4524, Number of files: 270
# Folder: delivery/4988, Number of files: 270
# Folder: delivery/5066, Number of files: 275
# Folder: delivery/4944, Number of files: 275
# Folder: delivery/5298, Number of files: 275
# Folder: delivery/5061, Number of files: 275
# Folder: delivery/5405, Number of files: 275
# Folder: delivery/4523, Number of files: 275
# Folder: delivery/5095, Number of files: 270
# Folder: delivery/4986, Number of files: 270
# Folder: delivery/5068, Number of files: 275
# Folder: delivery/4972, Number of files: 270
# Folder: delivery/5433, Number of files: 275
# Folder: delivery/5057, Number of files: 270
# Folder: delivery/4515, Number of files: 275
# Folder: delivery/4975, Number of files: 275
# Folder: delivery/4981, Number of files: 275
# Folder: delivery/4512, Number of files: 273
# Folder: delivery/4546, Number of files: 275
# Folder: delivery/1034, Number of files: 275
# Folder: delivery/4774, Number of files: 270
# Folder: delivery/5004, Number of files: 270
# Folder: delivery/4579, Number of files: 270
# Folder: delivery/4787, Number of files: 275
# Folder: delivery/739, Number of files: 275
# Folder: delivery/4773, Number of files: 270
# Folder: delivery/4541, Number of files: 275
# Folder: delivery/5451, Number of files: 275
# Folder: delivery/4577, Number of files: 275
# Folder: delivery/4910, Number of files: 275
# Folder: delivery/4548, Number of files: 273
# Folder: delivery/4326, Number of files: 271
# Folder: delivery/35, Number of files: 275
# Folder: delivery/4584, Number of files: 270
# Folder: delivery/5032, Number of files: 275
# Folder: delivery/4917, Number of files: 275
# Folder: delivery/4789, Number of files: 275
# Folder: delivery/5469, Number of files: 275
# Folder: delivery/4980, Number of files: 275
# Folder: delivery/5051, Number of files: 275
# Folder: delivery/4513, Number of files: 275
# Folder: delivery/4345, Number of files: 270
# Folder: delivery/5297, Number of files: 275
# Folder: delivery/4973, Number of files: 275
# Folder: delivery/4987, Number of files: 270
# Folder: delivery/4514, Number of files: 275
# Folder: delivery/4945, Number of files: 275
# Folder: delivery/67, Number of files: 275
# Folder: delivery/4522, Number of files: 271
# Folder: delivery/5404, Number of files: 275
# Folder: delivery/4942, Number of files: 270
# Folder: delivery/5403, Number of files: 275
# Folder: delivery/4989, Number of files: 270
# Folder: delivery/4525, Number of files: 270
# Folder: delivery/5033, Number of files: 275
# Folder: delivery/4929, Number of files: 270
# Folder: delivery/4327, Number of files: 270
# Folder: delivery/4788, Number of files: 270
# Folder: delivery/504, Number of files: 275
# Folder: delivery/4916, Number of files: 273
# Folder: delivery/4112, Number of files: 275
# Folder: delivery/5034, Number of files: 275
# Folder: delivery/4911, Number of files: 270
# Folder: delivery/4549, Number of files: 275
# Folder: delivery/4540, Number of files: 270
# Folder: delivery/4772, Number of files: 270
# Folder: delivery/4786, Number of files: 275
# Folder: delivery/5002, Number of files: 275
# Folder: delivery/4927, Number of files: 275
# Folder: delivery/4781, Number of files: 275
# Folder: delivery/4547, Number of files: 275
# Folder: delivery/4920, Number of files: 275
# Folder: delivery/4852, Number of files: 275
# Folder: delivery/5148, Number of files: 275
# Folder: delivery/4263, Number of files: 270
# Folder: delivery/4607, Number of files: 270
# Folder: delivery/4899, Number of files: 275
# Folder: delivery/5345, Number of files: 275
# Folder: delivery/4855, Number of files: 275
# Folder: delivery/5342, Number of files: 275
# Folder: delivery/2193, Number of files: 275
# Folder: delivery/5179, Number of files: 270
# Folder: delivery/4897, Number of files: 275
# Folder: delivery/485, Number of files: 275
# Folder: delivery/5374, Number of files: 275
# Folder: delivery/5380, Number of files: 275
# Folder: delivery/5387, Number of files: 275
# Folder: delivery/5327, Number of files: 275
# Folder: delivery/4830, Number of files: 275
# Folder: delivery/4468, Number of files: 270
# Folder: delivery/4808, Number of files: 270
# Folder: delivery/5329, Number of files: 275
# Folder: delivery/4801, Number of files: 275
# Folder: delivery/4839, Number of files: 270
# Folder: delivery/5311, Number of files: 275
# Folder: delivery/4806, Number of files: 275
# Folder: delivery/4891, Number of files: 270
# Folder: delivery/5372, Number of files: 275
# Folder: delivery/5386, Number of files: 275
# Folder: delivery/4862, Number of files: 275
# Folder: delivery/4896, Number of files: 270
# Folder: delivery/5178, Number of files: 270
# Folder: delivery/5381, Number of files: 275
# Folder: delivery/4405, Number of files: 275
# Folder: delivery/5147, Number of files: 275
# Folder: delivery/5375, Number of files: 275
# Folder: delivery/5388, Number of files: 275
# Folder: delivery/4854, Number of files: 275
# Folder: delivery/5185, Number of files: 270
# Folder: delivery/4291, Number of files: 275
# Folder: delivery/4639, Number of files: 270
# Folder: delivery/4853, Number of files: 275
# Folder: delivery/4898, Number of files: 275
# Folder: delivery/5310, Number of files: 275
# Folder: delivery/4460, Number of files: 270
# Folder: delivery/4800, Number of files: 270
# Folder: delivery/4809, Number of files: 275
# Folder: delivery/4451, Number of files: 270
# Folder: delivery/5326, Number of files: 275
# Folder: delivery/5319, Number of files: 275
# Folder: delivery/281, Number of files: 270
# Folder: delivery/4813, Number of files: 270
# Folder: delivery/4814, Number of files: 270
# Folder: delivery/4648, Number of files: 275
# Folder: delivery/4822, Number of files: 272
# Folder: delivery/4683, Number of files: 270
# Folder: delivery/5107, Number of files: 275
# Folder: delivery/5335, Number of files: 275
# Folder: delivery/4825, Number of files: 270
# Folder: delivery/850, Number of files: 275
# Folder: delivery/5100, Number of files: 275
# Folder: delivery/5366, Number of files: 275
# Folder: delivery/5392, Number of files: 275
# Folder: delivery/5359, Number of files: 275
# Folder: delivery/4885, Number of files: 270
# Folder: delivery/4871, Number of files: 275
# Folder: delivery/5395, Number of files: 275
# Folder: delivery/5361, Number of files: 275
# Folder: delivery/5198, Number of files: 270
# Folder: delivery/4278, Number of files: 275
# Folder: delivery/4615, Number of files: 270
# Folder: delivery/5357, Number of files: 275
# Folder: delivery/4840, Number of files: 270
# Folder: delivery/5368, Number of files: 275
# Folder: delivery/4282, Number of files: 275
# Folder: delivery/4878, Number of files: 270
# Folder: delivery/5196, Number of files: 270
# Folder: delivery/4276, Number of files: 270
# Folder: delivery/4612, Number of files: 270
# Folder: delivery/4824, Number of files: 275
# Folder: delivery/5333, Number of files: 275
# Folder: delivery/4685, Number of files: 270
# Folder: delivery/4649, Number of files: 275
# Folder: delivery/4823, Number of files: 275
# Folder: delivery/5106, Number of files: 275
# Folder: delivery/4676, Number of files: 270
# Folder: delivery/4815, Number of files: 275
# Folder: delivery/5302, Number of files: 275
# Folder: delivery/4472, Number of files: 270
# Folder: delivery/4812, Number of files: 275
# Folder: delivery/5108, Number of files: 275
# Folder: delivery/5305, Number of files: 275
# Folder: delivery/5197, Number of files: 275
# Folder: delivery/4879, Number of files: 275
# Folder: delivery/4613, Number of files: 275
# Folder: delivery/4283, Number of files: 275
# Folder: delivery/4248, Number of files: 275
# Folder: delivery/5356, Number of files: 275
# Folder: delivery/4614, Number of files: 275
# Folder: delivery/5190, Number of files: 270
# Folder: delivery/5369, Number of files: 275
# Folder: delivery/4841, Number of files: 275
# Folder: delivery/4419, Number of files: 270
# Folder: delivery/5152, Number of files: 275
# Folder: delivery/5360, Number of files: 275
# Folder: delivery/5394, Number of files: 275
# Folder: delivery/4883, Number of files: 275
# Folder: delivery/4877, Number of files: 275
# Folder: delivery/5393, Number of files: 275
# Folder: delivery/4241, Number of files: 270
# Folder: delivery/5367, Number of files: 275
# Folder: delivery/4870, Number of files: 275
# Folder: delivery/4768, Number of files: 275
# Folder: delivery/4902, Number of files: 275
# Folder: delivery/5443, Number of files: 275
# Folder: delivery/5027, Number of files: 275
# Folder: delivery/4333, Number of files: 270
# Folder: delivery/4905, Number of files: 275
# Folder: delivery/4334, Number of files: 270
# Folder: delivery/5020, Number of files: 275
# Folder: delivery/4933, Number of files: 270
# Folder: delivery/5029, Number of files: 275
# Folder: delivery/4766, Number of files: 270
# Folder: delivery/4792, Number of files: 270
# Folder: delivery/5472, Number of files: 275
# Folder: delivery/5016, Number of files: 275
# Folder: delivery/714, Number of files: 270
# Folder: delivery/4598, Number of files: 270
# Folder: delivery/4934, Number of files: 275
# Folder: delivery/5475, Number of files: 275
# Folder: delivery/4795, Number of files: 275
# Folder: delivery/5045, Number of files: 275
# Folder: delivery/4735, Number of files: 270
# Folder: delivery/4994, Number of files: 275
# Folder: delivery/4960, Number of files: 275
# Folder: delivery/4538, Number of files: 275
# Folder: delivery/4958, Number of files: 275
# Folder: delivery/4732, Number of files: 275
# Folder: delivery/5426, Number of files: 275
# Folder: delivery/5042, Number of files: 270
# Folder: delivery/4967, Number of files: 270
# Folder: delivery/4993, Number of files: 275
# Folder: delivery/5419, Number of files: 275
# Folder: delivery/4536, Number of files: 275
# Folder: delivery/5080, Number of files: 275
# Folder: delivery/4509, Number of files: 275
# Folder: delivery/5417, Number of files: 275
# Folder: delivery/5087, Number of files: 270
# Folder: delivery/4969, Number of files: 275
# Folder: delivery/4703, Number of files: 270
# Folder: delivery/4531, Number of files: 275
# Folder: delivery/5428, Number of files: 275
# Folder: delivery/5474, Number of files: 275
# Folder: delivery/5028, Number of files: 275
# Folder: delivery/4932, Number of files: 275
# Folder: delivery/4793, Number of files: 270
# Folder: delivery/4767, Number of files: 275
# Folder: delivery/5021, Number of files: 270
# Folder: delivery/4597, Number of files: 270
# Folder: delivery/4903, Number of files: 275
# Folder: delivery/4332, Number of files: 270
# Folder: delivery/21, Number of files: 270
# Folder: delivery/5442, Number of files: 275
# Folder: delivery/5026, Number of files: 275
# Folder: delivery/4366, Number of files: 275
# Folder: delivery/4530, Number of files: 275
# Folder: delivery/4702, Number of files: 275
# Folder: delivery/4957, Number of files: 275
# Folder: delivery/5429, Number of files: 275
# Folder: delivery/5075, Number of files: 275
# Folder: delivery/5411, Number of files: 275
# Folder: delivery/4537, Number of files: 275
# Folder: delivery/5081, Number of files: 275
# Folder: delivery/770, Number of files: 275
# Folder: delivery/4508, Number of files: 275
# Folder: delivery/5427, Number of files: 276
# Folder: delivery/5427/395, Number of files: 275
# Folder: delivery/5043, Number of files: 275
# Folder: delivery/4959, Number of files: 270
# Folder: delivery/1241, Number of files: 275
# Folder: delivery/4992, Number of files: 275
# Folder: delivery/5418, Number of files: 275
# Folder: delivery/4966, Number of files: 270
# Folder: delivery/4506, Number of files: 270
# Folder: delivery/4734, Number of files: 270
# Folder: delivery/5420, Number of files: 275
# Folder: delivery/4961, Number of files: 270
# Folder: delivery/4995, Number of files: 270
# Folder: delivery/5464, Number of files: 275
# Folder: delivery/4784, Number of files: 275
# Folder: delivery/4770, Number of files: 275
# Folder: delivery/395, Number of files: 275
# Folder: delivery/4777, Number of files: 275
# Folder: delivery/4922, Number of files: 275
# Folder: delivery/392, Number of files: 275
# Folder: delivery/5038, Number of files: 275
# Folder: delivery/4325, Number of files: 270
# Folder: delivery/5455, Number of files: 275
# Folder: delivery/5031, Number of files: 275
# Folder: delivery/4914, Number of files: 275
# Folder: delivery/5036, Number of files: 275
# Folder: delivery/5452, Number of files: 275
# Folder: delivery/4779, Number of files: 270
# Folder: delivery/5406, Number of files: 275
# Folder: delivery/4520, Number of files: 275
# Folder: delivery/4978, Number of files: 275
# Folder: delivery/4518, Number of files: 275
# Folder: delivery/4940, Number of files: 275
# Folder: delivery/5091, Number of files: 270
# Folder: delivery/4527, Number of files: 275
# Folder: delivery/5401, Number of files: 275
# Folder: delivery/5065, Number of files: 270
# Folder: delivery/4976, Number of files: 270
# Folder: delivery/5098, Number of files: 275
# Folder: delivery/100, Number of files: 275
# Folder: delivery/4511, Number of files: 275
# Folder: delivery/5295, Number of files: 275
# Folder: delivery/5053, Number of files: 270
# Folder: delivery/5437, Number of files: 275
# Folder: delivery/4985, Number of files: 275
# Folder: delivery/4529, Number of files: 275
# Folder: delivery/4516, Number of files: 270
# Folder: delivery/5037, Number of files: 275
# Folder: delivery/4912, Number of files: 270
# Folder: delivery/4778, Number of files: 275
# Folder: delivery/5008, Number of files: 275
# Folder: delivery/4586, Number of files: 270
# Folder: delivery/4915, Number of files: 275
# Folder: delivery/5006, Number of files: 275
# Folder: delivery/4785, Number of files: 270
# Folder: delivery/536, Number of files: 270
# Folder: delivery/4528, Number of files: 275
# Folder: delivery/4970, Number of files: 270
# Folder: delivery/4984, Number of files: 275
# Folder: delivery/4517, Number of files: 275
# Folder: delivery/5431, Number of files: 275
# Folder: delivery/333, Number of files: 275
# Folder: delivery/5099, Number of files: 275
# Folder: delivery/4977, Number of files: 270
# Folder: delivery/5052, Number of files: 270
# Folder: delivery/5436, Number of files: 275
# Folder: delivery/4510, Number of files: 275
# Folder: delivery/4948, Number of files: 270
# Folder: delivery/5294, Number of files: 275
# Folder: delivery/4519, Number of files: 275
# Folder: delivery/795, Number of files: 275
# Folder: delivery/4941, Number of files: 275
# Folder: delivery/97, Number of files: 275
# Folder: delivery/4526, Number of files: 275
# Folder: delivery/4946, Number of files: 275
# Folder: delivery/5438, Number of files: 275
# Folder: delivery/4521, Number of files: 275
# Folder: delivery/5097, Number of files: 275
# Folder: delivery/4979, Number of files: 275
# Folder: delivery/5407, Number of files: 275
# Folder: delivery/5323, Number of files: 275
# Folder: delivery/4833, Number of files: 270
# Folder: delivery/4805, Number of files: 270
# Folder: delivery/4802, Number of files: 275
# Folder: delivery/5341, Number of files: 275
# Folder: delivery/4851, Number of files: 270
# Folder: delivery/5379, Number of files: 275
# Folder: delivery/4260, Number of files: 275
# Folder: delivery/5180, Number of files: 270
# Folder: delivery/5346, Number of files: 275
# Folder: delivery/5189, Number of files: 270
# Folder: delivery/4867, Number of files: 275
# Folder: delivery/475, Number of files: 275
# Folder: delivery/4893, Number of files: 270
# Folder: delivery/4400, Number of files: 275
# Folder: delivery/5384, Number of files: 275
# Folder: delivery/5370, Number of files: 275
# Folder: delivery/4894, Number of files: 275
# Folder: delivery/4860, Number of files: 273
# Folder: delivery/5145, Number of files: 275
# Folder: delivery/5377, Number of files: 275
# Folder: delivery/5383, Number of files: 275
# Folder: delivery/4803, Number of files: 275
# Folder: delivery/5313, Number of files: 275
# Folder: delivery/4804, Number of files: 270
# Folder: delivery/5325, Number of files: 275
# Folder: delivery/5110, Number of files: 275
# Folder: delivery/4835, Number of files: 273
# Folder: delivery/4861, Number of files: 273
# Folder: delivery/4895, Number of files: 270
# Folder: delivery/5382, Number of files: 275
# Folder: delivery/5376, Number of files: 275
# Folder: delivery/4096, Number of files: 275
# Folder: delivery/5144, Number of files: 270
# Folder: delivery/4892, Number of files: 275
# Folder: delivery/4268, Number of files: 270
# Folder: delivery/4866, Number of files: 270
# Folder: delivery/5188, Number of files: 270
# Folder: delivery/5385, Number of files: 275
# Folder: delivery/5378, Number of files: 275
# Folder: delivery/4098, Number of files: 275
# Folder: delivery/5347, Number of files: 275
# Folder: delivery/4261, Number of files: 270
# Folder: delivery/4430, Number of files: 275
# Folder: delivery/4868, Number of files: 275
# Folder: delivery/5340, Number of files: 275
# Folder: delivery/5396, Number of files: 275
# Folder: delivery/4412, Number of files: 275
# Folder: delivery/5150, Number of files: 270
# Folder: delivery/4875, Number of files: 270
# Folder: delivery/4881, Number of files: 270
# Folder: delivery/5391, Number of files: 275
# Folder: delivery/4886, Number of files: 275
# Folder: delivery/4288, Number of files: 275
# Folder: delivery/4872, Number of files: 275
# Folder: delivery/5353, Number of files: 275
# Folder: delivery/5195, Number of files: 270
# Folder: delivery/4611, Number of files: 275
# Folder: delivery/664, Number of files: 275
# Folder: delivery/4844, Number of files: 275
# Folder: delivery/5398, Number of files: 275
# Folder: delivery/4888, Number of files: 275
# Folder: delivery/5354, Number of files: 275
# Folder: delivery/4843, Number of files: 275
# Folder: delivery/4817, Number of files: 275
# Folder: delivery/4828, Number of files: 275
# Folder: delivery/5338, Number of files: 275
# Folder: delivery/4673, Number of files: 270
# Folder: delivery/4819, Number of files: 275
# Folder: delivery/4821, Number of files: 273
# Folder: delivery/5309, Number of files: 275
# Folder: delivery/5336, Number of files: 275
# Folder: delivery/4273, Number of files: 270
# Folder: delivery/5194, Number of files: 270
# Folder: delivery/4610, Number of files: 270
# Folder: delivery/4422, Number of files: 275
# Folder: delivery/4845, Number of files: 275
# Folder: delivery/4414, Number of files: 270
# Folder: delivery/5390, Number of files: 275
# Folder: delivery/5364, Number of files: 275
# Folder: delivery/4873, Number of files: 275
# Folder: delivery/495, Number of files: 270
# Folder: delivery/5151, Number of files: 270
# Folder: delivery/5397, Number of files: 275
# Folder: delivery/4413, Number of files: 270
# Folder: delivery/492, Number of files: 275
# Folder: delivery/5308, Number of files: 275
# Folder: delivery/4820, Number of files: 275
# Folder: delivery/5105, Number of files: 275
# Folder: delivery/5337, Number of files: 275
# Folder: delivery/4675, Number of files: 275
# Folder: delivery/4447, Number of files: 275
# Folder: delivery/4827, Number of files: 275
# Folder: delivery/4818, Number of files: 275
# Folder: delivery/5330, Number of files: 275
# Folder: delivery/5102, Number of files: 275
# Folder: delivery/4686, Number of files: 201
# Folder: delivery/5306, Number of files: 275
# Folder: delivery/4816, Number of files: 275
# Folder: delivery/4829, Number of files: 275
# Folder: delivery/4503, Number of files: 275
# Folder: delivery/5041, Number of files: 275
# Folder: delivery/5046, Number of files: 270
# Folder: delivery/5422, Number of files: 275
# Folder: delivery/4504, Number of files: 275
# Folder: delivery/4736, Number of files: 274
# Folder: delivery/5079, Number of files: 275
# Folder: delivery/4963, Number of files: 275
# Folder: delivery/5414, Number of files: 275
# Folder: delivery/1888, Number of files: 270
# Folder: delivery/4390, Number of files: 270
# Folder: delivery/5084, Number of files: 275
# Folder: delivery/4532, Number of files: 273
# Folder: delivery/4700, Number of files: 275
# Folder: delivery/4955, Number of files: 270
# Folder: delivery/4535, Number of files: 275
# Folder: delivery/5083, Number of files: 275
# Folder: delivery/4999, Number of files: 275
# Folder: delivery/4397, Number of files: 270
# Folder: delivery/5413, Number of files: 275
# Folder: delivery/4798, Number of files: 270
# Folder: delivery/5478, Number of files: 275
# Folder: delivery/4753, Number of files: 275
# Folder: delivery/4337, Number of files: 270
# Folder: delivery/4939, Number of files: 275
# Folder: delivery/4901, Number of files: 270
# Folder: delivery/5440, Number of files: 275
# Folder: delivery/5449, Number of files: 275
# Folder: delivery/4937, Number of files: 275
# Folder: delivery/5012, Number of files: 275
# Folder: delivery/5476, Number of files: 275
# Folder: delivery/4550, Number of files: 275
# Folder: delivery/4908, Number of files: 275
# Folder: delivery/5471, Number of files: 275
# Folder: delivery/4791, Number of files: 270
# Folder: delivery/5227, Number of files: 270
# Folder: delivery/5015, Number of files: 274
# Folder: delivery/4998, Number of files: 270
# Folder: delivery/4534, Number of files: 275
# Folder: delivery/4150, Number of files: 275
# Folder: delivery/5082, Number of files: 275
# Folder: delivery/5049, Number of files: 270
# Folder: delivery/4953, Number of files: 275
# Folder: delivery/5085, Number of files: 275
# Folder: delivery/4701, Number of files: 270
# Folder: delivery/4533, Number of files: 275
# Folder: delivery/5415, Number of files: 275
# Folder: delivery/4954, Number of files: 275
# Folder: delivery/789, Number of files: 275
# Folder: delivery/4505, Number of files: 275
# Folder: delivery/5423, Number of files: 275
# Folder: delivery/4962, Number of files: 275
# Folder: delivery/4996, Number of files: 275
# Folder: delivery/4502, Number of files: 275
# Folder: delivery/4991, Number of files: 265
# Folder: delivery/4965, Number of files: 270
# Folder: delivery/1229, Number of files: 270
# Folder: delivery/4931, Number of files: 275
# Folder: delivery/4790, Number of files: 275
# Folder: delivery/5470, Number of files: 275
# Folder: delivery/5014, Number of files: 270
# Folder: delivery/4936, Number of files: 275
# Folder: delivery/4338, Number of files: 270
# Folder: delivery/4551, Number of files: 275
# Folder: delivery/4909, Number of files: 270
# Folder: delivery/5013, Number of files: 275
# Folder: delivery/4797, Number of files: 270
# Folder: delivery/4900, Number of files: 275
# Folder: delivery/5441, Number of files: 275
# Folder: delivery/5025, Number of files: 275
# Folder: delivery/5479, Number of files: 275
# Folder: delivery/4907, Number of files: 270
# Folder: delivery/5022, Number of files: 270
# Folder: delivery/5446, Number of files: 275
# Folder: delivery/4938, Number of files: 270
#
# Total number of files in the delivery folder: 137462

# %%
import os

def count_files_in_subfolders(main_folder):
    """
    This function walks through each subfolder of the main folder and counts the number of files in each.
    It also prints the total number of files in the delivery folder and lists folders with fewer than 275 files
    and exactly 275 files.
    """
    total_files = 0  # Initialize a counter for the total number of files
    folders_with_few_files = []  # List to store subfolders with fewer than 275 files
    folders_with_exact_files = []  # List to store subfolders with exactly 275 files
    
    for root, dirs, files in os.walk(main_folder):
        # Count files in the current directory
        subfolder_name = os.path.relpath(root, main_folder)
        file_count = len([f for f in files if os.path.isfile(os.path.join(root, f))])
        total_files += file_count  # Add to the total count
        
        # Print the file count for each folder
        #print(f"Folder: {subfolder_name}, Number of files: {file_count}")
        
        # Check the file count and store in the respective lists
        if file_count < 275:
            folders_with_few_files.append((subfolder_name, file_count))
        elif file_count >= 275:
            folders_with_exact_files.append((subfolder_name, file_count))
    
    # Print the total number of files
    #print(f"\nTotal number of files in the delivery folder: {total_files}")
    
    # Print folders with fewer than 275 files
    if folders_with_few_files:
        print("\nFolders with fewer than 275 files:")
        for folder, count in folders_with_few_files:
            print(f"Folder: {folder}, Number of files: {count}")
    else:
        print("\nAll folders have 275 or more files.")
    
    # Print folders with exactly 275 files
    if folders_with_exact_files:
        print("\nFolders with 275 or more files:")
        for folder, count in folders_with_exact_files:
            print(f"Folder: {folder}, Number of files: {count}")
    
    # Print total count of folders with fewer than 275 files and exactly 275 files
    print(f"\nTotal number of folders with fewer than 275 files: {len(folders_with_few_files)}")
    print(f"Total number of folders with exactly 275 files: {len(folders_with_exact_files)}")

# Example usage:
if __name__ == "__main__":
    main_folder_path = "/users/azizkhan/speakers"  # Replace with your main folder path
    count_files_in_subfolders(main_folder_path)
# Out:
# Folders with fewer than 275 files:
# Folder: ., Number of files: 1
# Folder: delivery, Number of files: 1
# Folder: delivery/4943, Number of files: 270
# Folder: delivery/4524, Number of files: 270
# Folder: delivery/4988, Number of files: 270
# Folder: delivery/5095, Number of files: 270
# Folder: delivery/4986, Number of files: 270
# Folder: delivery/4972, Number of files: 270
# Folder: delivery/5057, Number of files: 270
# Folder: delivery/4512, Number of files: 273
# Folder: delivery/4774, Number of files: 270
# Folder: delivery/5004, Number of files: 270
# Folder: delivery/4579, Number of files: 270
# Folder: delivery/4773, Number of files: 270
# Folder: delivery/4548, Number of files: 273
# Folder: delivery/4326, Number of files: 271
# Folder: delivery/4584, Number of files: 270
# Folder: delivery/4345, Number of files: 270
# Folder: delivery/4987, Number of files: 270
# Folder: delivery/4522, Number of files: 271
# Folder: delivery/4942, Number of files: 270
# Folder: delivery/4989, Number of files: 270
# Folder: delivery/4525, Number of files: 270
# Folder: delivery/4929, Number of files: 270
# Folder: delivery/4327, Number of files: 270
# Folder: delivery/4788, Number of files: 270
# Folder: delivery/4916, Number of files: 273
# Folder: delivery/4911, Number of files: 270
# Folder: delivery/4540, Number of files: 270
# Folder: delivery/4772, Number of files: 270
# Folder: delivery/4263, Number of files: 270
# Folder: delivery/4607, Number of files: 270
# Folder: delivery/5179, Number of files: 270
# Folder: delivery/4468, Number of files: 270
# Folder: delivery/4808, Number of files: 270
# Folder: delivery/4839, Number of files: 270
# Folder: delivery/4891, Number of files: 270
# Folder: delivery/4896, Number of files: 270
# Folder: delivery/5178, Number of files: 270
# Folder: delivery/5185, Number of files: 270
# Folder: delivery/4639, Number of files: 270
# Folder: delivery/4460, Number of files: 270
# Folder: delivery/4800, Number of files: 270
# Folder: delivery/4451, Number of files: 270
# Folder: delivery/281, Number of files: 270
# Folder: delivery/4813, Number of files: 270
# Folder: delivery/4814, Number of files: 270
# Folder: delivery/4822, Number of files: 272
# Folder: delivery/4683, Number of files: 270
# Folder: delivery/4825, Number of files: 270
# Folder: delivery/4885, Number of files: 270
# Folder: delivery/5198, Number of files: 270
# Folder: delivery/4615, Number of files: 270
# Folder: delivery/4840, Number of files: 270
# Folder: delivery/4878, Number of files: 270
# Folder: delivery/5196, Number of files: 270
# Folder: delivery/4276, Number of files: 270
# Folder: delivery/4612, Number of files: 270
# Folder: delivery/4685, Number of files: 270
# Folder: delivery/4676, Number of files: 270
# Folder: delivery/4472, Number of files: 270
# Folder: delivery/5190, Number of files: 270
# Folder: delivery/4419, Number of files: 270
# Folder: delivery/4241, Number of files: 270
# Folder: delivery/4333, Number of files: 270
# Folder: delivery/4334, Number of files: 270
# Folder: delivery/4933, Number of files: 270
# Folder: delivery/4766, Number of files: 270
# Folder: delivery/4792, Number of files: 270
# Folder: delivery/714, Number of files: 270
# Folder: delivery/4598, Number of files: 270
# Folder: delivery/4735, Number of files: 270
# Folder: delivery/5042, Number of files: 270
# Folder: delivery/4967, Number of files: 270
# Folder: delivery/5087, Number of files: 270
# Folder: delivery/4703, Number of files: 270
# Folder: delivery/4793, Number of files: 270
# Folder: delivery/5021, Number of files: 270
# Folder: delivery/4597, Number of files: 270
# Folder: delivery/4332, Number of files: 270
# Folder: delivery/21, Number of files: 270
# Folder: delivery/4959, Number of files: 270
# Folder: delivery/4966, Number of files: 270
# Folder: delivery/4506, Number of files: 270
# Folder: delivery/4734, Number of files: 270
# Folder: delivery/4961, Number of files: 270
# Folder: delivery/4995, Number of files: 270
# Folder: delivery/4325, Number of files: 270
# Folder: delivery/4779, Number of files: 270
# Folder: delivery/5091, Number of files: 270
# Folder: delivery/5065, Number of files: 270
# Folder: delivery/4976, Number of files: 270
# Folder: delivery/5053, Number of files: 270
# Folder: delivery/4516, Number of files: 270
# Folder: delivery/4912, Number of files: 270
# Folder: delivery/4586, Number of files: 270
# Folder: delivery/4785, Number of files: 270
# Folder: delivery/536, Number of files: 270
# Folder: delivery/4970, Number of files: 270
# Folder: delivery/4977, Number of files: 270
# Folder: delivery/5052, Number of files: 270
# Folder: delivery/4948, Number of files: 270
# Folder: delivery/4833, Number of files: 270
# Folder: delivery/4805, Number of files: 270
# Folder: delivery/4851, Number of files: 270
# Folder: delivery/5180, Number of files: 270
# Folder: delivery/5189, Number of files: 270
# Folder: delivery/4893, Number of files: 270
# Folder: delivery/4860, Number of files: 273
# Folder: delivery/4804, Number of files: 270
# Folder: delivery/4835, Number of files: 273
# Folder: delivery/4861, Number of files: 273
# Folder: delivery/4895, Number of files: 270
# Folder: delivery/5144, Number of files: 270
# Folder: delivery/4268, Number of files: 270
# Folder: delivery/4866, Number of files: 270
# Folder: delivery/5188, Number of files: 270
# Folder: delivery/4261, Number of files: 270
# Folder: delivery/5150, Number of files: 270
# Folder: delivery/4875, Number of files: 270
# Folder: delivery/4881, Number of files: 270
# Folder: delivery/5195, Number of files: 270
# Folder: delivery/4673, Number of files: 270
# Folder: delivery/4821, Number of files: 273
# Folder: delivery/4273, Number of files: 270
# Folder: delivery/5194, Number of files: 270
# Folder: delivery/4610, Number of files: 270
# Folder: delivery/4414, Number of files: 270
# Folder: delivery/495, Number of files: 270
# Folder: delivery/5151, Number of files: 270
# Folder: delivery/4413, Number of files: 270
# Folder: delivery/4686, Number of files: 201
# Folder: delivery/5046, Number of files: 270
# Folder: delivery/4736, Number of files: 274
# Folder: delivery/1888, Number of files: 270
# Folder: delivery/4390, Number of files: 270
# Folder: delivery/4532, Number of files: 273
# Folder: delivery/4955, Number of files: 270
# Folder: delivery/4397, Number of files: 270
# Folder: delivery/4798, Number of files: 270
# Folder: delivery/4337, Number of files: 270
# Folder: delivery/4901, Number of files: 270
# Folder: delivery/4791, Number of files: 270
# Folder: delivery/5227, Number of files: 270
# Folder: delivery/5015, Number of files: 274
# Folder: delivery/4998, Number of files: 270
# Folder: delivery/5049, Number of files: 270
# Folder: delivery/4701, Number of files: 270
# Folder: delivery/4991, Number of files: 265
# Folder: delivery/4965, Number of files: 270
# Folder: delivery/1229, Number of files: 270
# Folder: delivery/5014, Number of files: 270
# Folder: delivery/4338, Number of files: 270
# Folder: delivery/4909, Number of files: 270
# Folder: delivery/4797, Number of files: 270
# Folder: delivery/4907, Number of files: 270
# Folder: delivery/5022, Number of files: 270
# Folder: delivery/4938, Number of files: 270
#
# Folders with 275 or more files:
# Folder: consents, Number of files: 502
# Folder: delivery/5066, Number of files: 275
# Folder: delivery/4944, Number of files: 275
# Folder: delivery/5298, Number of files: 275
# Folder: delivery/5061, Number of files: 275
# Folder: delivery/5405, Number of files: 275
# Folder: delivery/4523, Number of files: 275
# Folder: delivery/5068, Number of files: 275
# Folder: delivery/5433, Number of files: 275
# Folder: delivery/4515, Number of files: 275
# Folder: delivery/4975, Number of files: 275
# Folder: delivery/4981, Number of files: 275
# Folder: delivery/4546, Number of files: 275
# Folder: delivery/1034, Number of files: 275
# Folder: delivery/4787, Number of files: 275
# Folder: delivery/739, Number of files: 275
# Folder: delivery/4541, Number of files: 275
# Folder: delivery/5451, Number of files: 275
# Folder: delivery/4577, Number of files: 275
# Folder: delivery/4910, Number of files: 275
# Folder: delivery/35, Number of files: 275
# Folder: delivery/5032, Number of files: 275
# Folder: delivery/4917, Number of files: 275
# Folder: delivery/4789, Number of files: 275
# Folder: delivery/5469, Number of files: 275
# Folder: delivery/4980, Number of files: 275
# Folder: delivery/5051, Number of files: 275
# Folder: delivery/4513, Number of files: 275
# Folder: delivery/5297, Number of files: 275
# Folder: delivery/4973, Number of files: 275
# Folder: delivery/4514, Number of files: 275
# Folder: delivery/4945, Number of files: 275
# Folder: delivery/67, Number of files: 275
# Folder: delivery/5404, Number of files: 275
# Folder: delivery/5403, Number of files: 275
# Folder: delivery/5033, Number of files: 275
# Folder: delivery/504, Number of files: 275
# Folder: delivery/4112, Number of files: 275
# Folder: delivery/5034, Number of files: 275
# Folder: delivery/4549, Number of files: 275
# Folder: delivery/4786, Number of files: 275
# Folder: delivery/5002, Number of files: 275
# Folder: delivery/4927, Number of files: 275
# Folder: delivery/4781, Number of files: 275
# Folder: delivery/4547, Number of files: 275
# Folder: delivery/4920, Number of files: 275
# Folder: delivery/4852, Number of files: 275
# Folder: delivery/5148, Number of files: 275
# Folder: delivery/4899, Number of files: 275
# Folder: delivery/5345, Number of files: 275
# Folder: delivery/4855, Number of files: 275
# Folder: delivery/5342, Number of files: 275
# Folder: delivery/2193, Number of files: 275
# Folder: delivery/4897, Number of files: 275
# Folder: delivery/485, Number of files: 275
# Folder: delivery/5374, Number of files: 275
# Folder: delivery/5380, Number of files: 275
# Folder: delivery/5387, Number of files: 275
# Folder: delivery/5327, Number of files: 275
# Folder: delivery/4830, Number of files: 275
# Folder: delivery/5329, Number of files: 275
# Folder: delivery/4801, Number of files: 275
# Folder: delivery/5311, Number of files: 275
# Folder: delivery/4806, Number of files: 275
# Folder: delivery/5372, Number of files: 275
# Folder: delivery/5386, Number of files: 275
# Folder: delivery/4862, Number of files: 275
# Folder: delivery/5381, Number of files: 275
# Folder: delivery/4405, Number of files: 275
# Folder: delivery/5147, Number of files: 275
# Folder: delivery/5375, Number of files: 275
# Folder: delivery/5388, Number of files: 275
# Folder: delivery/4854, Number of files: 275
# Folder: delivery/4291, Number of files: 275
# Folder: delivery/4853, Number of files: 275
# Folder: delivery/4898, Number of files: 275
# Folder: delivery/5310, Number of files: 275
# Folder: delivery/4809, Number of files: 275
# Folder: delivery/5326, Number of files: 275
# Folder: delivery/5319, Number of files: 275
# Folder: delivery/4648, Number of files: 275
# Folder: delivery/5107, Number of files: 275
# Folder: delivery/5335, Number of files: 275
# Folder: delivery/850, Number of files: 275
# Folder: delivery/5100, Number of files: 275
# Folder: delivery/5366, Number of files: 275
# Folder: delivery/5392, Number of files: 275
# Folder: delivery/5359, Number of files: 275
# Folder: delivery/4871, Number of files: 275
# Folder: delivery/5395, Number of files: 275
# Folder: delivery/5361, Number of files: 275
# Folder: delivery/4278, Number of files: 275
# Folder: delivery/5357, Number of files: 275
# Folder: delivery/5368, Number of files: 275
# Folder: delivery/4282, Number of files: 275
# Folder: delivery/4824, Number of files: 275
# Folder: delivery/5333, Number of files: 275
# Folder: delivery/4649, Number of files: 275
# Folder: delivery/4823, Number of files: 275
# Folder: delivery/5106, Number of files: 275
# Folder: delivery/4815, Number of files: 275
# Folder: delivery/5302, Number of files: 275
# Folder: delivery/4812, Number of files: 275
# Folder: delivery/5108, Number of files: 275
# Folder: delivery/5305, Number of files: 275
# Folder: delivery/5197, Number of files: 275
# Folder: delivery/4879, Number of files: 275
# Folder: delivery/4613, Number of files: 275
# Folder: delivery/4283, Number of files: 275
# Folder: delivery/4248, Number of files: 275
# Folder: delivery/5356, Number of files: 275
# Folder: delivery/4614, Number of files: 275
# Folder: delivery/5369, Number of files: 275
# Folder: delivery/4841, Number of files: 275
# Folder: delivery/5152, Number of files: 275
# Folder: delivery/5360, Number of files: 275
# Folder: delivery/5394, Number of files: 275
# Folder: delivery/4883, Number of files: 275
# Folder: delivery/4877, Number of files: 275
# Folder: delivery/5393, Number of files: 275
# Folder: delivery/5367, Number of files: 275
# Folder: delivery/4870, Number of files: 275
# Folder: delivery/4768, Number of files: 275
# Folder: delivery/4902, Number of files: 275
# Folder: delivery/5443, Number of files: 275
# Folder: delivery/5027, Number of files: 275
# Folder: delivery/4905, Number of files: 275
# Folder: delivery/5020, Number of files: 275
# Folder: delivery/5029, Number of files: 275
# Folder: delivery/5472, Number of files: 275
# Folder: delivery/5016, Number of files: 275
# Folder: delivery/4934, Number of files: 275
# Folder: delivery/5475, Number of files: 275
# Folder: delivery/4795, Number of files: 275
# Folder: delivery/5045, Number of files: 275
# Folder: delivery/4994, Number of files: 275
# Folder: delivery/4960, Number of files: 275
# Folder: delivery/4538, Number of files: 275
# Folder: delivery/4958, Number of files: 275
# Folder: delivery/4732, Number of files: 275
# Folder: delivery/5426, Number of files: 275
# Folder: delivery/4993, Number of files: 275
# Folder: delivery/5419, Number of files: 275
# Folder: delivery/4536, Number of files: 275
# Folder: delivery/5080, Number of files: 275
# Folder: delivery/4509, Number of files: 275
# Folder: delivery/5417, Number of files: 275
# Folder: delivery/4969, Number of files: 275
# Folder: delivery/4531, Number of files: 275
# Folder: delivery/5428, Number of files: 275
# Folder: delivery/5474, Number of files: 275
# Folder: delivery/5028, Number of files: 275
# Folder: delivery/4932, Number of files: 275
# Folder: delivery/4767, Number of files: 275
# Folder: delivery/4903, Number of files: 275
# Folder: delivery/5442, Number of files: 275
# Folder: delivery/5026, Number of files: 275
# Folder: delivery/4366, Number of files: 275
# Folder: delivery/4530, Number of files: 275
# Folder: delivery/4702, Number of files: 275
# Folder: delivery/4957, Number of files: 275
# Folder: delivery/5429, Number of files: 275
# Folder: delivery/5075, Number of files: 275
# Folder: delivery/5411, Number of files: 275
# Folder: delivery/4537, Number of files: 275
# Folder: delivery/5081, Number of files: 275
# Folder: delivery/770, Number of files: 275
# Folder: delivery/4508, Number of files: 275
# Folder: delivery/5427, Number of files: 276
# Folder: delivery/5427/395, Number of files: 275
# Folder: delivery/5043, Number of files: 275
# Folder: delivery/1241, Number of files: 275
# Folder: delivery/4992, Number of files: 275
# Folder: delivery/5418, Number of files: 275
# Folder: delivery/5420, Number of files: 275
# Folder: delivery/5464, Number of files: 275
# Folder: delivery/4784, Number of files: 275
# Folder: delivery/4770, Number of files: 275
# Folder: delivery/395, Number of files: 275
# Folder: delivery/4777, Number of files: 275
# Folder: delivery/4922, Number of files: 275
# Folder: delivery/392, Number of files: 275
# Folder: delivery/5038, Number of files: 275
# Folder: delivery/5455, Number of files: 275
# Folder: delivery/5031, Number of files: 275
# Folder: delivery/4914, Number of files: 275
# Folder: delivery/5036, Number of files: 275
# Folder: delivery/5452, Number of files: 275
# Folder: delivery/5406, Number of files: 275
# Folder: delivery/4520, Number of files: 275
# Folder: delivery/4978, Number of files: 275
# Folder: delivery/4518, Number of files: 275
# Folder: delivery/4940, Number of files: 275
# Folder: delivery/4527, Number of files: 275
# Folder: delivery/5401, Number of files: 275
# Folder: delivery/5098, Number of files: 275
# Folder: delivery/100, Number of files: 275
# Folder: delivery/4511, Number of files: 275
# Folder: delivery/5295, Number of files: 275
# Folder: delivery/5437, Number of files: 275
# Folder: delivery/4985, Number of files: 275
# Folder: delivery/4529, Number of files: 275
# Folder: delivery/5037, Number of files: 275
# Folder: delivery/4778, Number of files: 275
# Folder: delivery/5008, Number of files: 275
# Folder: delivery/4915, Number of files: 275
# Folder: delivery/5006, Number of files: 275
# Folder: delivery/4528, Number of files: 275
# Folder: delivery/4984, Number of files: 275
# Folder: delivery/4517, Number of files: 275
# Folder: delivery/5431, Number of files: 275
# Folder: delivery/333, Number of files: 275
# Folder: delivery/5099, Number of files: 275
# Folder: delivery/5436, Number of files: 275
# Folder: delivery/4510, Number of files: 275
# Folder: delivery/5294, Number of files: 275
# Folder: delivery/4519, Number of files: 275
# Folder: delivery/795, Number of files: 275
# Folder: delivery/4941, Number of files: 275
# Folder: delivery/97, Number of files: 275
# Folder: delivery/4526, Number of files: 275
# Folder: delivery/4946, Number of files: 275
# Folder: delivery/5438, Number of files: 275
# Folder: delivery/4521, Number of files: 275
# Folder: delivery/5097, Number of files: 275
# Folder: delivery/4979, Number of files: 275
# Folder: delivery/5407, Number of files: 275
# Folder: delivery/5323, Number of files: 275
# Folder: delivery/4802, Number of files: 275
# Folder: delivery/5341, Number of files: 275
# Folder: delivery/5379, Number of files: 275
# Folder: delivery/4260, Number of files: 275
# Folder: delivery/5346, Number of files: 275
# Folder: delivery/4867, Number of files: 275
# Folder: delivery/475, Number of files: 275
# Folder: delivery/4400, Number of files: 275
# Folder: delivery/5384, Number of files: 275
# Folder: delivery/5370, Number of files: 275
# Folder: delivery/4894, Number of files: 275
# Folder: delivery/5145, Number of files: 275
# Folder: delivery/5377, Number of files: 275
# Folder: delivery/5383, Number of files: 275
# Folder: delivery/4803, Number of files: 275
# Folder: delivery/5313, Number of files: 275
# Folder: delivery/5325, Number of files: 275
# Folder: delivery/5110, Number of files: 275
# Folder: delivery/5382, Number of files: 275
# Folder: delivery/5376, Number of files: 275
# Folder: delivery/4096, Number of files: 275
# Folder: delivery/4892, Number of files: 275
# Folder: delivery/5385, Number of files: 275
# Folder: delivery/5378, Number of files: 275
# Folder: delivery/4098, Number of files: 275
# Folder: delivery/5347, Number of files: 275
# Folder: delivery/4430, Number of files: 275
# Folder: delivery/4868, Number of files: 275
# Folder: delivery/5340, Number of files: 275
# Folder: delivery/5396, Number of files: 275
# Folder: delivery/4412, Number of files: 275
# Folder: delivery/5391, Number of files: 275
# Folder: delivery/4886, Number of files: 275
# Folder: delivery/4288, Number of files: 275
# Folder: delivery/4872, Number of files: 275
# Folder: delivery/5353, Number of files: 275
# Folder: delivery/4611, Number of files: 275
# Folder: delivery/664, Number of files: 275
# Folder: delivery/4844, Number of files: 275
# Folder: delivery/5398, Number of files: 275
# Folder: delivery/4888, Number of files: 275
# Folder: delivery/5354, Number of files: 275
# Folder: delivery/4843, Number of files: 275
# Folder: delivery/4817, Number of files: 275
# Folder: delivery/4828, Number of files: 275
# Folder: delivery/5338, Number of files: 275
# Folder: delivery/4819, Number of files: 275
# Folder: delivery/5309, Number of files: 275
# Folder: delivery/5336, Number of files: 275
# Folder: delivery/4422, Number of files: 275
# Folder: delivery/4845, Number of files: 275
# Folder: delivery/5390, Number of files: 275
# Folder: delivery/5364, Number of files: 275
# Folder: delivery/4873, Number of files: 275
# Folder: delivery/5397, Number of files: 275
# Folder: delivery/492, Number of files: 275
# Folder: delivery/5308, Number of files: 275
# Folder: delivery/4820, Number of files: 275
# Folder: delivery/5105, Number of files: 275
# Folder: delivery/5337, Number of files: 275
# Folder: delivery/4675, Number of files: 275
# Folder: delivery/4447, Number of files: 275
# Folder: delivery/4827, Number of files: 275
# Folder: delivery/4818, Number of files: 275
# Folder: delivery/5330, Number of files: 275
# Folder: delivery/5102, Number of files: 275
# Folder: delivery/5306, Number of files: 275
# Folder: delivery/4816, Number of files: 275
# Folder: delivery/4829, Number of files: 275
# Folder: delivery/4503, Number of files: 275
# Folder: delivery/5041, Number of files: 275
# Folder: delivery/5422, Number of files: 275
# Folder: delivery/4504, Number of files: 275
# Folder: delivery/5079, Number of files: 275
# Folder: delivery/4963, Number of files: 275
# Folder: delivery/5414, Number of files: 275
# Folder: delivery/5084, Number of files: 275
# Folder: delivery/4700, Number of files: 275
# Folder: delivery/4535, Number of files: 275
# Folder: delivery/5083, Number of files: 275
# Folder: delivery/4999, Number of files: 275
# Folder: delivery/5413, Number of files: 275
# Folder: delivery/5478, Number of files: 275
# Folder: delivery/4753, Number of files: 275
# Folder: delivery/4939, Number of files: 275
# Folder: delivery/5440, Number of files: 275
# Folder: delivery/5449, Number of files: 275
# Folder: delivery/4937, Number of files: 275
# Folder: delivery/5012, Number of files: 275
# Folder: delivery/5476, Number of files: 275
# Folder: delivery/4550, Number of files: 275
# Folder: delivery/4908, Number of files: 275
# Folder: delivery/5471, Number of files: 275
# Folder: delivery/4534, Number of files: 275
# Folder: delivery/4150, Number of files: 275
# Folder: delivery/5082, Number of files: 275
# Folder: delivery/4953, Number of files: 275
# Folder: delivery/5085, Number of files: 275
# Folder: delivery/4533, Number of files: 275
# Folder: delivery/5415, Number of files: 275
# Folder: delivery/4954, Number of files: 275
# Folder: delivery/789, Number of files: 275
# Folder: delivery/4505, Number of files: 275
# Folder: delivery/5423, Number of files: 275
# Folder: delivery/4962, Number of files: 275
# Folder: delivery/4996, Number of files: 275
# Folder: delivery/4502, Number of files: 275
# Folder: delivery/4931, Number of files: 275
# Folder: delivery/4790, Number of files: 275
# Folder: delivery/5470, Number of files: 275
# Folder: delivery/4936, Number of files: 275
# Folder: delivery/4551, Number of files: 275
# Folder: delivery/5013, Number of files: 275
# Folder: delivery/4900, Number of files: 275
# Folder: delivery/5441, Number of files: 275
# Folder: delivery/5025, Number of files: 275
# Folder: delivery/5479, Number of files: 275
# Folder: delivery/5446, Number of files: 275
#
# Total number of folders with fewer than 275 files: 158
# Total number of folders with exactly 275 files: 346
